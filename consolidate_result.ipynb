# %%
import pandas as pd

# %%
dantri_new = pd.read_excel('/Users/hieudt/VNU/Thesis/Dantri/2020-2023/dantri_result.xlsx')
dantri = pd.read_excel('/Users/hieudt/VNU/Thesis/dantri_result.xlsx')
df_1 = dantri[['Title_name', 'Title_link', 'Title_content', 'Title_time', 'Location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_1.columns = ['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']
df_2 = dantri_new[['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_2 = df_2[df_2['Year'].isin([2020, 2021, 2022])]
df_dantri = pd.concat([df_1, df_2])
df_dantri['paper'] = 'dantri'

# %%
nhandan_new = pd.read_excel('/Users/hieudt/VNU/Thesis/Nhandan/2020-2023/nhandan_result.xlsx')
nhandan = pd.read_excel('/Users/hieudt/VNU/Thesis/nhandan_result.xlsx')
df_1 = nhandan[['Title_name', 'Title_link', 'Title_content', 'Title_time', 'Location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_1.columns = ['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']
df_2 = nhandan_new[['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_2 = df_2[df_2['Year'].isin([2020, 2021, 2022])]
df_nhandan = pd.concat([df_1, df_2])
df_nhandan['paper'] = 'nhandan'

# %%
vnexpress_new = pd.read_excel('/Users/hieudt/VNU/Thesis/Vnexpress/2020-2023/vnexpress_result.xlsx')
vnexpress = pd.read_excel('/Users/hieudt/VNU/Thesis/vnexpress_result.xlsx')
df_1 = vnexpress[['Title_name', 'Title_link', 'Title_content', 'Title_time', 'Location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_1.columns = ['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']
df_2 = vnexpress_new[['news', 'news-href', 'content', 'time', 'location', 'Month', 'Quarter', 'Year', 'based_index', 'List_out']]
df_2 = df_2[df_2['Year'].isin([2020, 2021, 2022])]
df_vnexpress = pd.concat([df_1, df_2])
df_vnexpress['paper'] = 'vnexpress'

# %%
df_dantri.to_excel('/Users/hieudt/VNU/Thesis/Dantri/2020-2023/dantri_consolidate_result.xlsx')

# %%
df_nhandan.to_excel('/Users/hieudt/VNU/Thesis/Nhandan/2020-2023/nhandan_consolidate_result.xlsx')

# %%
df_vnexpress.to_excel('/Users/hieudt/VNU/Thesis/Vnexpress/2020-2023/vnexpress_consolidate_result.xlsx')

# %%
# Out:
#                                                   news  \
# 0    Đề nghị truy tố hai nguyên bộ trưởng cùng 12 đ...
# 1    Sở Y tế Hà Tĩnh kỷ luật chín cán bộ, công chức...
# 2          Chuẩn bị xét xử sơ thẩm vụ án Thiên Lợi Hòa
# 3    Chánh án Nguyễn Hòa Bình giải trình về các vụ ...
# 4    Viện Kiểm sát Nhân dân tối cao đề nghị sớm đưa...
# ..                                                 ...
# 228  Bắt tạm giam nguyên Tổng Giám đốc Tổng công ty...
# 229  Khởi tố, bắt tạm giam các bị can trong vụ án t...
# 230  Xét xử vụ án sai phạm tại cao tốc TP Hồ Chí Mi...
# 231         Hoạt động nhằm lật đổ chính quyền nhân dân
# 232  Bắt nguyên Giám đốc Ngân hàng Nhà nước chi nhá...
#
#                                              news-href  \
# 0    /thoi-su-phap-luat/de-nghi-truy-to-hai-nguyen-...
# 1    /thoi-su-phap-luat/Sở-Y-tế-Hà-Tĩnh-kỷ-luật-chí...
# 2    /thoi-su-phap-luat/chuan-bi-xet-xu-so-tham-vu-...
# 3    /thoi-su-phap-luat/chanh-an-nguyen-hoa-binh-gi...
# ...
